# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
newdf = df.drop(columns = ['Name','Ticket','Cabin','PassengerId','Pclass','SibSp','Parch'])
df1 = pd.get_dummies(newdf,dtype=int)

# %%
df1.corr()
# Out:
#             Survived       Age      Fare  Sex_female  Sex_male  Embarked_C  \
# Survived    1.000000 -0.077221  0.257307    0.543351 -0.543351    0.168240
# Age        -0.077221  1.000000  0.096067   -0.093254  0.093254    0.036261
# Fare        0.257307  0.096067  1.000000    0.182333 -0.182333    0.269335
# Sex_female  0.543351 -0.093254  0.182333    1.000000 -1.000000    0.082853
# Sex_male   -0.543351  0.093254 -0.182333   -1.000000  1.000000   -0.082853
# Embarked_C  0.168240  0.036261  0.269335    0.082853 -0.082853    1.000000
# Embarked_Q  0.003650 -0.022405 -0.117216    0.074115 -0.074115   -0.148258
# Embarked_S -0.155660 -0.032523 -0.166603   -0.125722  0.125722   -0.778359
#
#             Embarked_Q  Embarked_S
# Survived      0.003650   -0.155660
# Age          -0.022405   -0.032523
# Fare         -0.117216   -0.166603
# Sex_female    0.074115   -0.125722
# Sex_male     -0.074115    0.125722
# Embarked_C   -0.148258   -0.778359
# Embarked_Q    1.000000   -0.496624
# ...

# %%
x1 = df1.drop(columns = ['Survived'])
y1 = df['Survived']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.33)

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_train,y_train)
# Out:
# 0.8314606741573034

# %%
n = int(input())
for i in range(n):
    Sex_female,Sex_male,Embarked_C,Embarked_Q,Embarked_S = map(int,input().split(','))
    Age,Fare = map(float,input().split(','))
    print(model.predict([[Age,Fare,Sex_female,Sex_male,Embarked_C,Embarked_Q,Embarked_S]]))
# Out:
# 1
# 0,1,0,0,1
# 22.0,7.2500
# [0]
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
